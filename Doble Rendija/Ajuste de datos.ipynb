# %% [markdown]
# Importar librerias

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from scipy.optimize import curve_fit
Descargar = False
def residuos(y,yfit):
    return y-yfit

# %% [markdown]
# Datos del experimento Una rendija

# %%
#Valor y
Intensidad_una_rendija = np.array([0.051, 0.060, 0.07, 0.081, 0.094, 0.108, 0.125, 0.143, 0.163, 0.181, 0.2, 0.229, 0.250, 0.271, 0.291, 0.310, 0.329, 0.344, 0.356, 0.366, 0.373, 0.376, 0.376, 0.372, 0.364, 0.354, 0.341, 0.324, 0.306, 0.287, 0.266, 0.243, 0.215, 0.188, 0.161, 0.136, 0.117, 0.10])
#Valor x
Rotacion_una_rendija = np.arange(0,len(Intensidad_una_rendija)*20,20)
valor_x_maximo = Rotacion_una_rendija[np.argmax(Intensidad_una_rendija)]
Rotacion_una_rendija = Rotacion_una_rendija-valor_x_maximo
#Error
e_y_una_rendija = 0.0005*np.ones(len(Intensidad_una_rendija))

# %% [markdown]
# Datos del experimento Doble rendija

# %%
#Eje y
Intensidad_dos_rendijas=np.array([13.4, 13.81, 13.66, 13.5, 13.34, 13.16, 13.03, 12.83, 12.57, 12.32, 12.1, 11.89, 11.7, 11.35, 11.04, 10.83, 10.56, 10.31, 10.1, 9.77, 9.45, 9.11, 8.98,8.67, 8.40, 8.16, 8.03, 7.91, 7.71, 7.57, 7.41, 7.29, 7.17, 7.08, 6.91, 6.82, 6.69, 6.57, 6.51, 6.41, 6.36, 6.25, 6.18, 6.13, 6.05, 5.94, 5.89, 5.84, 5.76, 5.61, 5.54, 5.42, 5.27, 5.21, 5.04, 4.92, 4.794, 4.71, 4.52, 4.44, 4.21, 4.08, 3.87, 3.75, 3.61, 3.48, 3.22, 3.1, 2.92, 2.75, 2.6, 2.27, 2.18, 2.07, 1.9, 1.8, 1.69, 1.58, 1.46, 1.35, 1.25, 1.18, 1.06, 1.01, 0.92, 0.893, 0.766, 0.725, 0.690, 0.641, 0.571, 0.512, 0.484, 0.455, 0.416, 0.363, 0.344, 0.307, 0.291, 0.283, 0.268, 0.262, 0.249, 0.240, 0.231, 0.222, 0.21, 0.199, 0.189, 0.177, 0.165, 0.155, 0.142, 0.136, 0.132, 0.127, 0.124, 0.120, 0.116, 0.114, 0.109, 0.105, 0.102, 0.096, 0.092, 0.088, 0.085, 0.08, 0.076, 0.071, 0.067, 0.061, 0.058, 0.053, 0.05, 0.048, 0.046, 0.044, 0.043, 0.042, 0.04, 0.039, 0.0380, 0.034, 0.033, 0.032, 0.032, 0.032, 0.034, 0.036, 0.037, 0.038, 0.040, 0.042, 0.043, 0.047, 0.05, 0.053, 0.056, 0.059, 0.061, 0.065, 0.066, 0.071, 0.074, 0.076, 0.081, 0.083, 0.086, 0.086, 0.089, 0.091, 0.092, 0.092, 0.091, 0.089, 0.087, 0.084, 0.082, 0.078, 0.076, 0.073, 0.071, 0.068, 0.065, 0.061, 0.057, 0.054, 0.052, 0.05, 0.049, 0.049, 0.05, 0.051, 0.052, 0.056, 0.058, 0.061, 0.067, 0.075, 0.079, 0.087, 0.096, 0.105, 0.112, 0.119, 0.127, 0.137, 0.146, 0.152, 0.161, 0.169, 0.178, 0.184, 0.191, 0.197, 0.201, 0.205, 0.208, 0.208, 0.209, 0.205, 
227, 0.24, 0.255, 0.269, 0.283, 0.296, 0.308, 0.316, 0.333, 0.348, 0.352, 0.36, 0.371, 0.378, 0.389, 0.401, 0.411, 0.42, 0.435, 0.445, 0.458, 0.469, 0.477, 0.485, 0.49, 0.497, 0.5, 0.504, 0.506, 0.506, 0.505, 0.501, 0.494, 0.486, 0.476, 0.465, 0.459, 0.443, 0.431, 0.426, 0.412, 0.4, 0.381, 0.37, 0.357, 0.346, 0.333, 0.310, 0.292, 0.272, 0.271, 0.252, 0.24, 0.222, 0.196, 0.178, 0.161, 0.14, 0.132, 0.109, 0.095, 0.087, 0.081, 0.074, 0.069, 0.065, 0.062, 0.057, 0.055, 0.052, 0.051, 0.049, 0.048, 0.047, 0.048, 0.049, 0.051, 0.053, 0.055, 0.058, 0.06, 0.061, 0.062, 0.062, 0.061, 0.059, 0.059, 0.06, 0.063, 0.069, 0.072, 0.075, 0.078, 0.08, 0.083, 0.088, 0.094, 0.099, 0.101, 0.106, 0.11, 0.115, 0.121, 0.129, 0.137, 0.145, 0.155, 0.161, 0.174, 0.181, 0.189, 0.201, 0.2211, 0.220, 0.233, 0.243, 0.255, 0.267, 0.279, 0.29, 0.308, 0.316, 0.327, 0.342, 0.345, 0.356, 0.369, 0.389, 0.403, 0.414, 0.430, 0.443, 0.458, 0.469, 0.477, 0.493, 0.502, 0.512, 0.523, 0.545, 0.56, 0.573, 0.589, 0.599, 0.608, 0.617, 0.621, 0.636, 0.646, 0.66, 0.71, 0.692, 0.7, 0.725, 0.775, 0.783, 0.799, 0.812, 0.822, 0.83, 0.839, 0.84, 0.86, 0.883])
filtro_doble_rendija = Intensidad_dos_rendijas[155:-90]
#Eje x
Rotacion_dos_rendijas = np.arange(0,len(Intensidad_dos_rendijas)*2,2)
Rotacion_filtro = Rotacion_dos_rendijas[155:-90]
valor_x_maximo = Rotacion_filtro[np.argmax(filtro_doble_rendija)]
Rotacion_filtro = Rotacion_filtro-valor_x_maximo
Rotacion_dos_rendijas=Rotacion_dos_rendijas-valor_x_maximo
#Error
e_y_doble_rendija = 0.0005*np.ones(len(filtro_doble_rendija))
#plotear filtro
plt.semilogy(Rotacion_dos_rendijas, Intensidad_dos_rendijas)
plt.semilogy(Rotacion_filtro, filtro_doble_rendija)
plt.show()
if Descargar:
    ruta = os.getcwd()
    name =semiology+".png"
    ruta_completa = f"{ruta}/{name}"
    plt.savefig(ruta_completa, bbox_inches='tight', pad_inches=1.0)

# %% [markdown]
# Ajuste una rendija

# %%
#campana de gauss equación
def gauss(x,a,b,c):
    return a*np.exp(-((x-b)**2)/(2*c**2))
res_1, con_1 = curve_fit(gauss,Rotacion_una_rendija,Intensidad_una_rendija,p0=[np.max(Intensidad_una_rendija),np.max(Rotacion_una_rendija)/2,1000])
guass_fit = gauss(Rotacion_una_rendija,*res_1)

# %% [markdown]
# Gráfica de una rendija

# %%
Descargar = False
fig, axs = plt.subplots(3, 1, figsize=(8, 12), sharex=True, gridspec_kw={'hspace': 0})
axs[0].errorbar(Rotacion_una_rendija, Intensidad_una_rendija, fmt='o', label='Datos')
axs[0].plot(Rotacion_una_rendija, guass_fit, label="Ajuste Gaussiano")
label_text = f'Parámetros ajustados:\nA={res_1[0]:.2f}, $\\mu$={res_1[1]:.2f}, $\\sigma$={res_1[2]:.2f}'
axs[0].text(0.05, 0.95, label_text, transform=axs[0].transAxes, fontsize=10, verticalalignment='top')
axs[0].legend()  # Utiliza axs[0].legend() en lugar de plt.legend()
axs[0].set_ylabel("Intensidad [V/mV]")

# Subgráfico 1
axs[1].scatter(Rotacion_una_rendija, residuos(Intensidad_una_rendija, guass_fit))
axs[1].set_ylabel('Residuos [V/mV]')

# Subgráfico 2 (comentado para este ejemplo)
# axs[2].scatter(x, normalize_residuales)
# axs[2].set_ylabel('Residuos Normalizados')

plt.xlabel('Longitud[m]')
plt.tight_layout()

# Muestra el gráfico
plt.show()
if Descargar:
    ruta = os.getcwd()
    name = una_rendija+".png"
    ruta_completa = f"{ruta}/{name}"
    plt.savefig(ruta_completa, bbox_inches='tight', pad_inches=1.0)

# %%
plt.imshow(np.log(np.abs(con_1)))
plt.colorbar()
plt.show()

# %% [markdown]
# Ajuste de dos rendijas

# %%
def sinc(x,a,b,c,d):
    return a*np.sinc((x-c)/b)+d
def sinc_cos(x,a,b,c,d):
    return a*np.sinc((x-c)/b)*np.cos((x-c)/d)
def ajuste(theta,I,lamb,d,a,b,c):
    f =I*np.cos(np.sin((theta-c)/b)*np.pi*d/lamb)**2
    g =I*(np.sin(np.pi*a*np.sin((theta-c)/b)/lamb)/(np.pi*a*np.sin((theta-c)/b)/lamb))**2
    return f*g
res_2, con_2 = curve_fit(ajuste,Rotacion_filtro,filtro_doble_rendija,p0=[np.max(filtro_doble_rendija)**(1/2),10,100,50,480,1500])
print(res_2)
res_3, con_3 = curve_fit(sinc_cos,Rotacion_filtro,filtro_doble_rendija,p0=[np.max(filtro_doble_rendija)**(1/2),60,0,10])

doble_rendija_fit = ajuste(Rotacion_filtro,*res_2)
doble_rendija_fit_2 = sinc_cos(Rotacion_filtro,*res_3)+0.45
plt.plot(Rotacion_filtro,doble_rendija_fit)
plt.plot(Rotacion_filtro,doble_rendija_fit_2)
# Out:
# [8.76410438e-01 3.59032428e+04 1.06552258e+06 1.72481855e+05
#  3.46332391e+03 1.08886731e+04]

# %% [markdown]
# Gráfica de doble Rendija

# %%
fig2, axs2 = plt.subplots(3, 1, figsize=(8, 12), sharex=True, gridspec_kw={'hspace': 0})
axs2[0].errorbar(Rotacion_filtro, filtro_doble_rendija, yerr=e_y_doble_rendija, fmt='o')       
axs2[0].plot(Rotacion_filtro,doble_rendija_fit)
axs2[0].plot(Rotacion_filtro,doble_rendija_fit_2)
axs2[1].scatter(Rotacion_filtro,residuos(filtro_doble_rendija,doble_rendija_fit))
axs2[1].scatter(Rotacion_filtro,residuos(filtro_doble_rendija,doble_rendija_fit_2))
axs2[1].set_ylabel('Residuales')
#axs2[2].scatter(x,normalize_residuales)
#axs2[0].set_ylabel('Eje-y')

#axs2[2].set_ylabel('Residuales Normalizados')
plt.xlabel('X')
plt.tight_layout()
if Descargar:
    ruta = os.getcwd()
    name = dos_rendijas+".png"
    ruta_completa = f"{ruta}/{name}"
    plt.savefig(ruta_completa, bbox_inches='tight', pad_inches=1.0)

# %%
plt.imshow(np.log(np.abs(con_2)))
plt.colorbar()
plt.show()
