# %% [markdown]
# En esta parte se encuentra codigo de los mínimos cuadrados y con incertidumbre

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([1, 2, 3, 4, 5])

# Generar valores de y (con ruido gaussiano)
y = 2 * x + 1 + np.random.normal(0, 1, len(x))

# Generar valores de incertidumbre (pueden variar para cada punto)
i = np.array([0.5, 0.6, 0.7, 0.8, 0.9])

# Graficar los puntos con barras de error
plt.errorbar(x, y, yerr=i, fmt='o', label='Datos con incertidumbre')

def minimos_cuadrados(x,y):
    n = len(x)
    sum_x = np.sum(x)
    sum_y = np.sum(y)
    sum_xy = np.sum(x*y)
    sum_x_2 = np.sum(x**2)
    pendiente = (n*sum_xy-(sum_x*sum_y))/(n*sum_x_2-(abs(sum_x)**2))
    intercepto = (sum_y*sum_x_2-sum_x*np.sum(x*y))/(n*sum_x_2-(abs(sum_x)**2))
    return pendiente,intercepto

m,b = minimos_cuadrados(x,y)
print(m,b)
# Añadir etiquetas y título
plt.plot(x,m*x+b)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Regresión Lineal con Incertidumbre')
plt.legend()

# Mostrar la gráfica
plt.show()
# Out:
# 1.894233682353847 1.391626174359667

# %% [markdown]
# Minimos cuadrados con incertidumbre

# %%
def minimos_cuadrados_incertidumbre(x,y,i):
    w = 1/(i**2)
    sum_w_x_2 = np.sum((x**2)*w)
    sum_w_y = np.sum(w*y)
    sum_w_x = np.sum(w*x)
    sum_w_x_y = np.sum(w*x*y)
    sum_w = np.sum(w)
    delta_prima = (sum_w*sum_w_x_2)-(sum_w_x)**2 
    pendiente = ((sum_w*sum_w_x_y)-(sum_w_x*sum_w_y))/delta_prima
    intercepto = ((sum_w_x_2*sum_w_y)-(sum_w_x*sum_w_x_y))/delta_prima
    error_inter = np.sqrt(sum_w_x_2/delta_prima)
    error_m = np.sqrt(sum_w/delta_prima)
    return pendiente,intercepto, error_inter, error_m

m,b,e_m,e_b = minimos_cuadrados_incertidumbre(x,y,i)
print(m,b)
# Añadir etiquetas y título
plt.errorbar(x, y, yerr=incertidumbre, fmt='o', label='Datos con incertidumbre')
m,b = minimos_cuadrados(x,y)
plt.plot(x,m*x+b)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Regresión Lineal con Incertidumbre')
plt.legend()

# Mostrar la gráfica
plt.show()
# Out:
# 1.8392052725246684 1.5499483989935505
